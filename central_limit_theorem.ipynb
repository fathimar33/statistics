# %%
#generate population
import random
import numpy as np
import seaborn as sns

# %%
a=[np.random.normal(60,12) for i in range(10001)]

# %%
sns.kdeplot(a)
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np

# Define your array 'a' here

n = 0
sample = []
while n < 100:
    np.random.shuffle(a)
    selected_elements = a[:30]
    sample.append(np.array(list(selected_elements)).mean())
    n += 1

sample
# Out:
# [60.034403523680496,
#  59.92949375684789,
#  61.2856080826964,
#  59.004742042769315,
#  59.77385611527042,
#  57.280439368437754,
#  59.9774730101846,
#  61.223692211310194,
#  61.46680724810601,
#  62.19752872283464,
#  58.54633132880986,
#  55.32300976425285,
#  58.37072983354862,
#  57.2620234433708,
#  58.54858814335789,
#  60.96969675222237,
#  62.17439015572557,
#  59.81649670653497,
#  58.71389450082757,
#  61.78039852866271,
#  57.574042482890846,
#  59.037888764695495,
#  60.23388066143352,
#  61.631159279280105,
#  59.081262085623415,
#  59.139089345621414,
#  60.966995690339424,
#  61.459920317068544,
#  57.111766147194075,
#  60.55765475939088,
#  58.83959772306096,
#  58.590030531356994,
#  57.267163029905056,
#  61.12426957193274,
#  57.96184407085939,
#  60.221178548497704,
#  57.63524299648825,
#  60.46042404268496,
#  60.962912433532566,
#  59.35188645166293,
#  61.414245750520415,
#  59.48913261872456,
#  58.26638476247054,
#  61.80893815322259,
# ...

# %%
sns.kdeplot(a)
sns.kdeplot(sample)
# Out:
# <Axes: ylabel='Density'>
